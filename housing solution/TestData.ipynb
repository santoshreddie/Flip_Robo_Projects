# %%
#importing necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
#here ia m loading the test dataset tooo
test_df = pd.read_csv("test.csv")

# %%
#head of the dataset
test_df.head()
# Out:
#      Id  MSSubClass MSZoning  ...  YrSold  SaleType SaleCondition
# 0   337          20       RL  ...    2007        WD        Normal
# 1  1018         120       RL  ...    2009       COD       Abnorml
# 2   929          20       RL  ...    2009        WD        Normal
# 3  1148          70       RL  ...    2009        WD        Normal
# 4  1227          60       RL  ...    2008        WD        Normal
#
# [5 rows x 80 columns]

# %%
print("shape of the data:", test_df.shape)
# Out:
# shape of the data: (292, 80)

# %%
#getting reputative values along with the null values of the dataset
for i in test_df:
  print(i)
  print(test_df[i].value_counts())
  print(test_df[i].isnull().sum())
  print()
# Out:
# Id
# 56      1
# 1217    1
# 1185    1
# 162     1
# 676     1
#        ..
# 340     1
# 855     1
# 858     1
# 1371    1
# 512     1
# Name: Id, Length: 292, dtype: int64
# 0
#
# MSSubClass
# 20     108
# 60      55
# 50      31
# 120     18
# 30      17
# 160     16
# 80      15
# 90      11
# 70       7
# 190      4
# 180      4
# 75       2
# 45       2
# 85       1
# 40       1
# Name: MSSubClass, dtype: int64
# 0
#
# MSZoning
# RL         223
# RM          55
# FV          13
# C (all)      1
# Name: MSZoning, dtype: int64
# 0
#
# LotFrontage
# 60.0     32
# 85.0     14
# 50.0     13
# 70.0     12
# 80.0      9
#          ..
# 124.0     1
# 71.0      1
# 138.0     1
# 34.0      1
# 69.0      1
# Name: LotFrontage, Length: 65, dtype: int64
# 45
#
# LotArea
# 7200     7
# 1680     4
# 7500     3
# 5400     3
# 8450     3
#         ..
# 10335    1
# 14157    1
# 7599     1
# 8520     1
# 12800    1
# Name: LotArea, Length: 249, dtype: int64
# 0
#
# Street
# Pave    290
# ...

# %%
#dropping the unnecessary columns
test_df.drop(['Alley','GarageYrBlt','PoolQC','Fence','MiscFeature','Id', 'Utilities'], axis = 1, inplace = True)

# %%
#Replacing the null va;ues based on the apprpriate method
test_df['LotFrontage']=test_df['LotFrontage'].fillna(test_df['LotFrontage'].mean())
test_df['MSZoning']=test_df['MSZoning'].fillna(test_df['MSZoning'].mode()[0])
test_df['BsmtCond']=test_df['BsmtCond'].fillna(test_df['BsmtCond'].mode()[0])
test_df['BsmtQual']=test_df['BsmtQual'].fillna(test_df['BsmtQual'].mode()[0])
test_df['FireplaceQu']=test_df['FireplaceQu'].fillna(test_df['FireplaceQu'].mode()[0])
test_df['GarageType']=test_df['GarageType'].fillna(test_df['GarageType'].mode()[0])
test_df['GarageFinish']=test_df['GarageFinish'].fillna(test_df['GarageFinish'].mode()[0])
test_df['GarageQual']=test_df['GarageQual'].fillna(test_df['GarageQual'].mode()[0])
test_df['GarageCond']=test_df['GarageCond'].fillna(test_df['GarageCond'].mode()[0])
test_df['MasVnrType']=test_df['MasVnrType'].fillna(test_df['MasVnrType'].mode()[0])
test_df['MasVnrArea']=test_df['MasVnrArea'].fillna(test_df['MasVnrArea'].mode()[0])
test_df['BsmtExposure']=test_df['BsmtExposure'].fillna(test_df['BsmtExposure'].mode()[0])
test_df['BsmtFinType1']=test_df['BsmtFinType1'].fillna(test_df['BsmtFinType1'].mode()[0])
test_df['BsmtFinType2']=test_df['BsmtFinType2'].fillna(test_df['BsmtFinType2'].mode()[0])
test_df['Electrical']=test_df['Electrical'].fillna(test_df['Electrical'].mode()[0])

# %%
#getting test info 
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 292 entries, 0 to 291
# Data columns (total 73 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     292 non-null    int64
#  1   MSZoning       292 non-null    object
#  2   LotFrontage    292 non-null    float64
#  3   LotArea        292 non-null    int64
#  4   Street         292 non-null    object
#  5   LotShape       292 non-null    object
#  6   LandContour    292 non-null    object
#  7   LotConfig      292 non-null    object
#  8   LandSlope      292 non-null    object
#  9   Neighborhood   292 non-null    object
#  10  Condition1     292 non-null    object
#  11  Condition2     292 non-null    object
#  12  BldgType       292 non-null    object
#  13  HouseStyle     292 non-null    object
#  14  OverallQual    292 non-null    int64
#  15  OverallCond    292 non-null    int64
#  16  YearBuilt      292 non-null    int64
# ...

# %%
#validating weather we have any null values or not
sns.heatmap(test_df.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
#checking the head again
test_df.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  ...  YrSold SaleType SaleCondition
# 0          20       RL    86.000000  ...    2007       WD        Normal
# 1         120       RL    66.425101  ...    2009      COD       Abnorml
# 2          20       RL    66.425101  ...    2009       WD        Normal
# 3          70       RL    75.000000  ...    2009       WD        Normal
# 4          60       RL    86.000000  ...    2008       WD        Normal
#
# [5 rows x 73 columns]

# %%
test_df.shape
# Out:
# (292, 73)

# %%
#saving the cleaned dataset
test_df.to_csv("formulated_test_df.csv")
